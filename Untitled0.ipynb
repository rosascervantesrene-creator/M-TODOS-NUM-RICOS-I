# %% [markdown]
# <a href="https://colab.research.google.com/github/rosascervantesrene-creator/M-TODOS-NUM-RICOS-I/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
  return np.exp(x**2)

# %%
xx=np.linspace(-1.1,1.1,100)
plt.plot(xx, f(xx))
